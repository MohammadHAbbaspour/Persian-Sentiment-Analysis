# %%
! pip install -q accelerate datasets evaluate sacremoses
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.9/270.9 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 19.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 12.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 20.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.5 MB/s eta 0:00:00

# %%
# !pip install git+https://github.com/Dadmatech/DadmaTools.git
# Out:
# Collecting git+https://github.com/Dadmatech/DadmaTools.git
#   Cloning https://github.com/Dadmatech/DadmaTools.git to /tmp/pip-req-build-67s2o3sx
#   Running command git clone --filter=blob:none --quiet https://github.com/Dadmatech/DadmaTools.git /tmp/pip-req-build-67s2o3sx
#   Resolved https://github.com/Dadmatech/DadmaTools.git to commit d84e5f4db24173b3f2bb7a7c768bd21640e13d32
#   Preparing metadata (setup.py) ... done
# Collecting bpemb>=0.3.3 (from dadmatools==2.0.0)
#   Downloading bpemb-0.3.4-py3-none-any.whl (19 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from dadmatools==2.0.0) (3.8.1)
# Requirement already satisfied: folium>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from dadmatools==2.0.0) (0.14.0)
# Requirement already satisfied: spacy>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from dadmatools==2.0.0) (3.6.1)
# Requirement already satisfied: torch>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from dadmatools==2.0.0) (2.1.0+cu121)
# Requirement already satisfied: transformers>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from dadmatools==2.0.0) (4.35.2)
# Requirement already satisfied: h5py>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from dadmatools==2.0.0) (3.9.0)
# Collecting Deprecated==1.2.6 (from dadmatools==2.0.0)
#   Downloading Deprecated-1.2.6-py2.py3-none-any.whl (8.1 kB)
# Requirement already satisfied: hyperopt>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from dadmatools==2.0.0) (0.2.7)
# Collecting pyconll>=3.1.0 (from dadmatools==2.0.0)
#   Downloading pyconll-3.2.0-py3-none-any.whl (27 kB)
# Collecting pytorch-transformers>=1.1.0 (from dadmatools==2.0.0)
#   Downloading pytorch_transformers-1.2.0-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.4/176.4 kB 4.3 MB/s eta 0:00:00
# Collecting segtok>=1.5.7 (from dadmatools==2.0.0)
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Requirement already satisfied: tabulate>=0.8.6 in /usr/local/lib/python3.10/dist-packages (from dadmatools==2.0.0) (0.9.0)
# Collecting supar==1.1.2 (from dadmatools==2.0.0)
#   Downloading supar-1.1.2-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.9/87.9 kB 12.7 MB/s eta 0:00:00
# Requirement already satisfied: gensim>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from dadmatools==2.0.0) (4.3.2)
# Collecting conllu (from dadmatools==2.0.0)
#   Downloading conllu-4.5.3-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: gdown>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from dadmatools==2.0.0) (4.7.3)
# Collecting py7zr>=0.17.2 (from dadmatools==2.0.0)
#   Downloading py7zr-0.20.8-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 9.1 MB/s eta 0:00:00
# Collecting html2text (from dadmatools==2.0.0)
#   Downloading html2text-2020.1.16-py3-none-any.whl (32 kB)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109 (from dadmatools==2.0.0)
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from dadmatools==2.0.0) (1.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from dadmatools==2.0.0) (1.23.5)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from dadmatools==2.0.0) (3.20.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from dadmatools==2.0.0) (2.31.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from dadmatools==2.0.0) (4.66.1)
# Collecting langid==1.1.6 (from dadmatools==2.0.0)
#   Downloading langid-1.1.6.tar.gz (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 14.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from dadmatools==2.0.0) (3.13.1)
# Requirement already satisfied: tokenizers>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from dadmatools==2.0.0) (0.15.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from dadmatools==2.0.0) (2023.6.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from dadmatools==2.0.0) (23.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from dadmatools==2.0.0) (0.1.99)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.10/dist-packages (from dadmatools==2.0.0) (0.1.1)
# Collecting fasttext (from dadmatools==2.0.0)
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 10.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting kenlm (from dadmatools==2.0.0)
#   Downloading kenlm-0.2.0.tar.gz (427 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.4/427.4 kB 20.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from Deprecated==1.2.6->dadmatools==2.0.0) (1.14.1)
# Collecting stanza (from supar==1.1.2->dadmatools==2.0.0)
#   Downloading stanza-1.7.0-py3-none-any.whl (933 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 933.2/933.2 kB 22.3 MB/s eta 0:00:00
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from supar==1.1.2->dadmatools==2.0.0) (0.3.7)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium>=0.2.1->dadmatools==2.0.0) (0.7.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium>=0.2.1->dadmatools==2.0.0) (3.1.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown>=4.3.1->dadmatools==2.0.0) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown>=4.3.1->dadmatools==2.0.0) (4.11.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim>=3.6.0->dadmatools==2.0.0) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim>=3.6.0->dadmatools==2.0.0) (6.4.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.5->dadmatools==2.0.0) (3.2.1)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.5->dadmatools==2.0.0) (0.18.3)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.5->dadmatools==2.0.0) (2.2.1)
# Requirement already satisfied: py4j in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.5->dadmatools==2.0.0) (0.10.9.7)
# Collecting texttable (from py7zr>=0.17.2->dadmatools==2.0.0)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Collecting pycryptodomex>=3.16.0 (from py7zr>=0.17.2->dadmatools==2.0.0)
#   Downloading pycryptodomex-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 31.3 MB/s eta 0:00:00
# Collecting pyzstd>=0.15.9 (from py7zr>=0.17.2->dadmatools==2.0.0)
#   Downloading pyzstd-0.15.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (412 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.3/412.3 kB 35.0 MB/s eta 0:00:00
# Collecting pyppmd<1.2.0,>=1.1.0 (from py7zr>=0.17.2->dadmatools==2.0.0)
#   Downloading pyppmd-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.9/138.9 kB 22.3 MB/s eta 0:00:00
# Collecting pybcj<1.1.0,>=1.0.0 (from py7zr>=0.17.2->dadmatools==2.0.0)
#   Downloading pybcj-1.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 7.4 MB/s eta 0:00:00
# Collecting multivolumefile>=0.2.3 (from py7zr>=0.17.2->dadmatools==2.0.0)
#   Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Collecting inflate64<1.1.0,>=1.0.0 (from py7zr>=0.17.2->dadmatools==2.0.0)
#   Downloading inflate64-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 14.5 MB/s eta 0:00:00
# Collecting brotli>=1.1.0 (from py7zr>=0.17.2->dadmatools==2.0.0)
#   Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 41.6 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from py7zr>=0.17.2->dadmatools==2.0.0) (5.9.5)
# Collecting boto3 (from pytorch-transformers>=1.1.0->dadmatools==2.0.0)
#   Downloading boto3-1.34.33-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.2->dadmatools==2.0.0) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.2->dadmatools==2.0.0) (3.2.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->dadmatools==2.0.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->dadmatools==2.0.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->dadmatools==2.0.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->dadmatools==2.0.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->dadmatools==2.0.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->dadmatools==2.0.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->dadmatools==2.0.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->dadmatools==2.0.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->dadmatools==2.0.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->dadmatools==2.0.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->dadmatools==2.0.0) (0.11.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->dadmatools==2.0.0) (1.10.14)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->dadmatools==2.0.0) (67.7.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->dadmatools==2.0.0) (3.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->dadmatools==2.0.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->dadmatools==2.0.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->dadmatools==2.0.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->dadmatools==2.0.0) (2023.11.17)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.7.0->dadmatools==2.0.0) (0.20.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->dadmatools==2.0.0) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->dadmatools==2.0.0) (1.12)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->dadmatools==2.0.0) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->dadmatools==2.0.0) (2.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.9.1->dadmatools==2.0.0) (6.0.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.9.1->dadmatools==2.0.0) (0.4.2)
# Collecting pybind11>=2.2 (from fasttext->dadmatools==2.0.0)
#   Using cached pybind11-2.11.1-py3-none-any.whl (227 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->dadmatools==2.0.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium>=0.2.1->dadmatools==2.0.0) (2.1.4)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.10.0->spacy>=3.0.0->dadmatools==2.0.0) (0.1.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=3.0.0->dadmatools==2.0.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=3.0.0->dadmatools==2.0.0) (0.1.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown>=4.3.1->dadmatools==2.0.0) (2.5)
# Collecting botocore<1.35.0,>=1.34.33 (from boto3->pytorch-transformers>=1.1.0->dadmatools==2.0.0)
#   Downloading botocore-1.34.33-py3-none-any.whl (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 63.5 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->pytorch-transformers>=1.1.0->dadmatools==2.0.0)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3->pytorch-transformers>=1.1.0->dadmatools==2.0.0)
#   Downloading s3transfer-0.10.0-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests->dadmatools==2.0.0) (1.7.1)
# Collecting emoji (from stanza->supar==1.1.2->dadmatools==2.0.0)
#   Downloading emoji-2.10.1-py2.py3-none-any.whl (421 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 44.7 MB/s eta 0:00:00
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from stanza->supar==1.1.2->dadmatools==2.0.0) (0.10.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7.1->dadmatools==2.0.0) (1.3.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.35.0,>=1.34.33->boto3->pytorch-transformers>=1.1.0->dadmatools==2.0.0) (2.8.2)
# Building wheels for collected packages: dadmatools, langid, fasttext, kenlm
#   Building wheel for dadmatools (setup.py) ... done
#   Created wheel for dadmatools: filename=dadmatools-2.0.0-py3-none-any.whl size=882993 sha256=8a3d105b3a4bf7bdabfb191780eea7c1508e435adb54f95b6386fb35553ce84e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w6en6t10/wheels/1b/17/0b/3ec9506c586bcdc9614338f1b15440cf2b72edeff8f0950c7c
#   Building wheel for langid (setup.py) ... done
#   Created wheel for langid: filename=langid-1.1.6-py3-none-any.whl size=1941172 sha256=5d23b8ba708e0743dbbadc3fc7b5479a6a8ed7f4695bef0c1884489dc82bde61
#   Stored in directory: /root/.cache/pip/wheels/23/c8/c6/eed80894918490a175677414d40bd7c851413bbe03d4856c3c
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4199773 sha256=d3d231c3b5e47e5c5416ff1afdf414f09f3585fc7d13389f0cc4ce51a4f68a29
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
#   Building wheel for kenlm (pyproject.toml) ... done
#   Created wheel for kenlm: filename=kenlm-0.2.0-cp310-cp310-linux_x86_64.whl size=3184427 sha256=a03db1d7f097b4910be5d0068926f28927859d73cce79eeafe1dd3af1bb4cdbf
#   Stored in directory: /root/.cache/pip/wheels/fd/80/e0/18f4148e863fb137bd87e21ee2bf423b81b3ed6989dab95135
# Successfully built dadmatools langid fasttext kenlm
# Installing collected packages: tf-estimator-nightly, texttable, kenlm, brotli, segtok, pyzstd, pyppmd, pycryptodomex, pyconll, pybind11, pybcj, multivolumefile, langid, jmespath, inflate64, html2text, emoji, Deprecated, conllu, py7zr, fasttext, botocore, stanza, s3transfer, bpemb, boto3, supar, pytorch-transformers, dadmatools
# Successfully installed Deprecated-1.2.6 boto3-1.34.33 botocore-1.34.33 bpemb-0.3.4 brotli-1.1.0 conllu-4.5.3 dadmatools-2.0.0 emoji-2.10.1 fasttext-0.9.2 html2text-2020.1.16 inflate64-1.0.0 jmespath-1.0.1 kenlm-0.2.0 langid-1.1.6 multivolumefile-0.2.3 py7zr-0.20.8 pybcj-1.0.2 pybind11-2.11.1 pyconll-3.2.0 pycryptodomex-3.20.0 pyppmd-1.1.0 pytorch-transformers-1.2.0 pyzstd-0.15.9 s3transfer-0.10.0 segtok-1.5.11 stanza-1.7.0 supar-1.1.2 texttable-1.7.0 tf-estimator-nightly-2.8.0.dev2021122109

# %%
import torch
import torch.nn as nn
import numpy as np
from datasets import load_dataset
import evaluate
from sklearn.metrics import f1_score, accuracy_score, recall_score, precision_score
from transformers import AutoConfig, AutoModelForSequenceClassification, AutoTokenizer, AutoModel
from transformers import TrainingArguments, Trainer
from transformers import DataCollatorWithPadding, EvalPrediction
from transformers.optimization import AdamW
from time import time
from dadmatools.normalizer import Normalizer
from huggingface_hub import notebook_login
from transformers import set_seed


SEED = 42
set_seed(SEED)
torch.manual_seed(SEED)
np.random.seed(SEED)

# %%
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
normalizer = Normalizer(
    full_cleaning=False,
    unify_chars=True,
    refine_punc_spacing=True,
    remove_extra_space=True,
    remove_puncs=False,
    remove_html=True,
    remove_stop_word=False,
    replace_email_with="<EMAIL>",
    replace_number_with=None,
    replace_url_with="",
    replace_mobile_number_with=None,
    replace_emoji_with="",
    replace_home_number_with=None
)

# %%
classes = ['HAPPY', 'SAD', 'ANGRY', 'FEAR', 'SURPRISE', 'HATE', 'OTHER']
class2id = {classes[i]: i for i in range(len(classes))}
id2class = {i: classes[i] for i in range(len(classes))}

def sigmoid(X):
    return 1 / (1 + np.exp(-X))

def heaviside(X):
    return np.heaviside(X - 0.5, 0)

def onehot(ids, size=len(classes)):
  result = np.zeros((ids.shape[0], size))
  result[np.arange(ids.shape[0]), ids] = 1
  return result

def compute_metrics(eval_preds: EvalPrediction):
  logits, labels = eval_preds.predictions, eval_preds.label_ids
  predictions = onehot(np.argmax(sigmoid(logits), axis=-1))

  f1 = f1_score(labels, predictions, average=None, zero_division=0.0)
  f1 = {f'f1_C{i}': f1[i] for i in range(len(f1))}
  f1_macro = f1_score(labels, predictions, average='macro', zero_division=0.0)
  recall = recall_score(labels, predictions, average=None, zero_division=0.0)
  recall = {f'recall_C{i}': recall[i] for i in range(len(recall))}
  recall_macro = recall_score(labels, predictions, average='macro', zero_division=0.0)
  precision = precision_score(labels, predictions, average=None, zero_division=0.0)
  precision = {f'precision_C{i}': precision[i] for i in range(len(precision))}
  precision_macro = precision_score(labels, predictions, average='macro', zero_division=0.0)
  accuracy = accuracy_score(labels, predictions)
  results = {'accuracy': accuracy, 'precision_macro': precision_macro, 'recall_macro': recall_macro, 'f1_macro': f1_macro, **f1, **recall, **precision}
  return results

# %%
ds_url = f'/content/'
ds_files = {
    'train': ds_url + 'pptrain.tsv',
    'test': ds_url + 'pptest.tsv',
}

ds = load_dataset('csv', data_files=ds_files, delimiter='\t')
ds = ds.rename_columns({'ID': 'id', 'Text': 'text', 'Label': 'label'})

ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'text', 'label'],
#         num_rows: 6125
#     })
#     test: Dataset({
#         features: ['id', 'text', 'label'],
#         num_rows: 1151
#     })
# })

# %%
def convert_labels(example):
  example["label"] = [float(num) for num in example['label'][1:-1].split(' ')]
  return example

def replace_none_with_str(example):
  if example['text'] == None:
    example['text'] = ''
  return example

def remove_hashtag(example):
  while '#' in example['text']:
    example['text'] = example['text'].replace('#', '')
  return example

ds = ds.map(convert_labels)
ds = ds.map(replace_none_with_str)
ds = ds.map(remove_hashtag)
print(ds['train'].features)
print(ds['test'].features)

# %%
num_epochs = 5
checkpoint = 'HooshvareLab/bert-base-parsbert-uncased'

# %%
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
def tokenize_function(example):
  example['text'] = [normalizer.normalize(t) for t in example['text']]
  return tokenizer(example['text'], truncation=True, max_length=512, add_special_tokens=True)

tokenized_datasets = ds.map(tokenize_function, batched=True)
data_collator = DataCollatorWithPadding(tokenizer)
# Out:
# Map:   0%|          | 0/6125 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1151 [00:00<?, ? examples/s]

# %%
tokenized_datasets['train'].features
# Out:
# {'id': Value(dtype='int64', id=None),
#  'text': Value(dtype='string', id=None),
#  'label': Sequence(feature=Value(dtype='float64', id=None), length=-1, id=None),
#  'input_ids': Sequence(feature=Value(dtype='int32', id=None), length=-1, id=None),
#  'token_type_ids': Sequence(feature=Value(dtype='int8', id=None), length=-1, id=None),
#  'attention_mask': Sequence(feature=Value(dtype='int8', id=None), length=-1, id=None)}

# %%
config = AutoConfig.from_pretrained(checkpoint)
config.update({
    'id2label': id2class,
    'label2id': class2id,
    'num_labels': 7
})
model = AutoModelForSequenceClassification.from_pretrained(checkpoint, num_labels=7)
model.config = config
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at HooshvareLab/bert-base-parsbert-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.config
# Out:
# BertConfig {
#   "_name_or_path": "HooshvareLab/bert-base-parsbert-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "HAPPY",
#     "1": "SAD",
#     "2": "ANGRY",
#     "3": "FEAR",
#     "4": "SURPRISE",
#     "5": "HATE",
#     "6": "OTHER"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "ANGRY": 2,
#     "FEAR": 3,
#     "HAPPY": 0,
#     "HATE": 5,
#     "OTHER": 6,
#     "SAD": 1,
#     "SURPRISE": 4
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.35.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 100000
# }

# %%
training_args = TrainingArguments(
    run_name=f'First Run-{time()}',
    output_dir='finetuned-parsbert-uncased-ArmanEmo',
    overwrite_output_dir=True,
    auto_find_batch_size=True,
    num_train_epochs=num_epochs,
    evaluation_strategy='epoch',
    eval_steps=512,
    save_strategy='epoch',
    save_steps=512,
    save_total_limit=5,
    load_best_model_at_end=True,
    metric_for_best_model='f1_macro',
    save_safetensors=True,
    group_by_length=True,
    push_to_hub=True,
    hub_model_id='mohammadhabp/finetuned-parsbert-uncased-ArmanEmo',
    hub_strategy='all_checkpoints',
    hub_token='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',
    warmup_steps=500,
    weight_decay=4e-3,
    seed=SEED,
    data_seed=SEED
)

# %%
trainer = Trainer(
    model,
    training_args,
    train_dataset=tokenized_datasets['train'],
    eval_dataset=tokenized_datasets['test'],
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)

# %%
train_output = trainer.train()
# Out:
#     <div>
#
#       <progress value='3830' max='3830' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3830/3830 09:37, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision Macro</th>
#       <th>Recall Macro</th>
#       <th>F1 Macro</th>
#       <th>F1 C0</th>
#       <th>F1 C1</th>
#       <th>F1 C2</th>
#       <th>F1 C3</th>
#       <th>F1 C4</th>
#       <th>F1 C5</th>
#       <th>F1 C6</th>
#       <th>Recall C0</th>
#       <th>Recall C1</th>
#       <th>Recall C2</th>
#       <th>Recall C3</th>
#       <th>Recall C4</th>
#       <th>Recall C5</th>
#       <th>Recall C6</th>
#       <th>Precision C0</th>
#       <th>Precision C1</th>
#       <th>Precision C2</th>
#       <th>Precision C3</th>
#       <th>Precision C4</th>
#       <th>Precision C5</th>
#       <th>Precision C6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.356400</td>
#       <td>0.308483</td>
#       <td>0.526499</td>
#       <td>0.592312</td>
#       <td>0.553024</td>
#       <td>0.519167</td>
#       <td>0.278788</td>
#       <td>0.675573</td>
#       <td>0.604905</td>
#       <td>0.696296</td>
#       <td>0.508475</td>
#       <td>0.392523</td>
#       <td>0.477612</td>
#       <td>0.167273</td>
#       <td>0.675573</td>
#       <td>0.720779</td>
#       <td>0.824561</td>
#       <td>0.413793</td>
#       <td>0.323077</td>
#       <td>0.746114</td>
#       <td>0.836364</td>
#       <td>0.675573</td>
#       <td>0.521127</td>
#       <td>0.602564</td>
#       <td>0.659341</td>
#       <td>0.500000</td>
#       <td>0.351220</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.188900</td>
#       <td>0.253978</td>
#       <td>0.631625</td>
#       <td>0.643413</td>
#       <td>0.620141</td>
#       <td>0.624656</td>
#       <td>0.690432</td>
#       <td>0.655008</td>
#       <td>0.600707</td>
#       <td>0.704000</td>
#       <td>0.582677</td>
#       <td>0.588235</td>
#       <td>0.551532</td>
#       <td>0.669091</td>
#       <td>0.786260</td>
#       <td>0.551948</td>
#       <td>0.771930</td>
#       <td>0.510345</td>
#       <td>0.538462</td>
#       <td>0.512953</td>
#       <td>0.713178</td>
#       <td>0.561308</td>
#       <td>0.658915</td>
#       <td>0.647059</td>
#       <td>0.678899</td>
#       <td>0.648148</td>
#       <td>0.596386</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.105200</td>
#       <td>0.293454</td>
#       <td>0.635100</td>
#       <td>0.638887</td>
#       <td>0.622609</td>
#       <td>0.624787</td>
#       <td>0.681648</td>
#       <td>0.691145</td>
#       <td>0.620482</td>
#       <td>0.618182</td>
#       <td>0.601504</td>
#       <td>0.587302</td>
#       <td>0.573248</td>
#       <td>0.661818</td>
#       <td>0.610687</td>
#       <td>0.668831</td>
#       <td>0.596491</td>
#       <td>0.551724</td>
#       <td>0.569231</td>
#       <td>0.699482</td>
#       <td>0.702703</td>
#       <td>0.796020</td>
#       <td>0.578652</td>
#       <td>0.641509</td>
#       <td>0.661157</td>
#       <td>0.606557</td>
#       <td>0.485612</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.050600</td>
#       <td>0.401063</td>
#       <td>0.634231</td>
#       <td>0.690402</td>
#       <td>0.625502</td>
#       <td>0.632684</td>
#       <td>0.625000</td>
#       <td>0.753153</td>
#       <td>0.609319</td>
#       <td>0.701754</td>
#       <td>0.539130</td>
#       <td>0.637931</td>
#       <td>0.562500</td>
#       <td>0.490909</td>
#       <td>0.797710</td>
#       <td>0.551948</td>
#       <td>0.701754</td>
#       <td>0.427586</td>
#       <td>0.569231</td>
#       <td>0.839378</td>
#       <td>0.859873</td>
#       <td>0.713311</td>
#       <td>0.680000</td>
#       <td>0.701754</td>
#       <td>0.729412</td>
#       <td>0.725490</td>
#       <td>0.422977</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.025800</td>
#       <td>0.425367</td>
#       <td>0.624674</td>
#       <td>0.676093</td>
#       <td>0.624860</td>
#       <td>0.627774</td>
#       <td>0.603248</td>
#       <td>0.736842</td>
#       <td>0.617544</td>
#       <td>0.711864</td>
#       <td>0.563025</td>
#       <td>0.610169</td>
#       <td>0.551724</td>
#       <td>0.472727</td>
#       <td>0.748092</td>
#       <td>0.571429</td>
#       <td>0.736842</td>
#       <td>0.462069</td>
#       <td>0.553846</td>
#       <td>0.829016</td>
#       <td>0.833333</td>
#       <td>0.725926</td>
#       <td>0.671756</td>
#       <td>0.688525</td>
#       <td>0.720430</td>
#       <td>0.679245</td>
#       <td>0.413437</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
trainer.save_model()
trainer.push_to_hub('fine tuned model')
# Out:
# CommitInfo(commit_url='https://huggingface.co/mohammadhabp/finetuned-parsbert-uncased-ArmanEmo/commit/770231c1803ea5332e6e5b72d65d8f7aacbed7f6', commit_message='fine tuned model', commit_description='', oid='770231c1803ea5332e6e5b72d65d8f7aacbed7f6', pr_url=None, pr_revision=None, pr_num=None)
